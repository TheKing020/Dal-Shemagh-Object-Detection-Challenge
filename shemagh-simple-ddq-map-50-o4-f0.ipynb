# %%
import IPython.display as display
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/torch-1.12.1+cu116-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/torchvision-0.13.1+cu116-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/mmcv-2.0.1-cp310-cp310-manylinux1_x86_64.whl 
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/openmim-0.3.9-py2.py3-none-any.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/mmengine-0.7.4-py3-none-any.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/addict-2.4.0-py3-none-any.whl
# !pip install yapf==0.40.1
display.clear_output()

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection
# !pip install -v -e .

# !mkdir checkpoint
# !mkdir outputs
# !mkdir data
# !mkdir data/images
# !mkdir data/labels

display.clear_output()

# %%
import torch, torchvision,mmdet
print("torch=",torch.__version__,torch.cuda.is_available())
print("mmdet=",mmdet.__version__)
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# torch= 1.12.1+cu116 True
# mmdet= 3.3.0
# 11.6
# GCC 9.3

# %%
import os
import io
import shutil
from PIL import Image

# %%
# !ls /kaggle/input/notebooks/kagglertw/dal-shemagh-2-f0
# Out:
# __notebook__.ipynb  __results__.html   custom.css
# __output__.json     __results___files  shemagh

# %%
from pycocotools.coco import COCO


annotation_file = '/kaggle/input/notebooks/kagglertw/dal-shemagh-2-f0/shemagh/train_dataset.json'


coco = COCO(annotation_file)


categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}


for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Category ID: 0, Category Name: head
# Category ID: 1, Category Name: shemagh

# %%
# !wget https://download.openmmlab.com/mmdetection/v3.0/ddq/ddq_detr_swinl_30e.pth -P ./checkpoints
display.clear_output()

# %%
from mmengine import Config
cfg = Config.fromfile('configs/ddq/ddq-detr-4scale_swinl_8xb2-30e_coco.py')

# %%
# !mkdir -p /kaggle/working/data
# !cp -r /kaggle/input/notebooks/kagglertw/data-management-5f/data_5fold/fold_0/* /kaggle/working/data/

# %%
# !ls /kaggle/input/notebooks/kagglertw/dal-shemagh-2-f0/shemagh
# Out:
# train  train_dataset.json  val	val_dataset.json

# %%
# !mkdir /kaggle/working/data
# Out:
# mkdir: cannot create directory '/kaggle/working/data': File exists

# %%
# !ls /kaggle/input/notebooks/kagglertw/data-management-5f/data_5fold/fold_0/
# Out:
# train  val

# %%
def count_png_files(folder_path):
    count = 0
    for file in os.listdir(folder_path):
        if file.lower().endswith(".jpg"):
            count += 1
    return count

# %%
# !mkdir /kaggle/working/data/val/images
# !mkdir /kaggle/working/data/train/images

# %%
# !mv /kaggle/working/data/val/*.jpg /kaggle/working/data/val/images/
# !mv /kaggle/working/data/train/*.jpg /kaggle/working/data/train/images/

# %%
# !ls /kaggle/working/data/val/
# Out:
# _annotations.coco.json	images

# %%
# !ls /kaggle/working/data/train/
# Out:
# _annotations.coco.json	images

# %%
# !ls /kaggle/working/data
# Out:
# train  val

# %%
count_png_files("/kaggle/working/data/val/images")
# Out:
# 135

# %%
count_png_files("/kaggle/working/data/train/images")
# Out:
# 516

# %%
config_car = """
_base_ = './ddq-detr-4scale_swinl_8xb2-30e_coco.py'

data_root = '/kaggle/working/data/'

train_batch_size_per_gpu = 1
train_num_workers = 2

max_epochs = 50

metainfo = {
    'classes': ('head', 'shemagh'),
    'palette': [(127,201,127),(190,174,212)]
}


train_pipeline = [
    dict(type='LoadImageFromFile', backend_args=_base_.backend_args),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='RandomFlip', prob=0.5),
    dict(type='ColorJitter', brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    dict(type='CLAHE', clip_limit=2.0, tile_grid_size=(8, 8)),
    dict(type='GaussianBlur', sigma_range=(0.1, 2.0)),
    dict(type='RandomAffine', scaling=(0.9, 1.1), translation=(0.1, 0.1), rotate=(-20, 20)),
    dict(type='RandomBrightnessContrast', brightness_limit=0.3, contrast_limit=0.3, prob=0.3),
    dict(type='Sharpen', alpha=(0.1, 0.3), lightness=(0.75, 1.5)),
    
    dict(
        type='RandomChoice',
        transforms=[
            [
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 1280)],
                    keep_ratio=True)
            ],
            [
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 4200)],
                    keep_ratio=True),
                dict(
                    type='RandomCrop',
                    crop_type='absolute_range',
                    crop_size=(384, 640),
                    allow_negative_crop=True),
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 1280)],
                    keep_ratio=True)
            ]
        ]),
    dict(type='PackDetInputs')
]

test_pipeline = [
    dict(type='LoadImageFromFile', backend_args=None),
    dict(type='Resize', scale=(1280, 1280), keep_ratio=True),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(
        type='PackDetInputs',
        meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
                   'scale_factor'))
]

train_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='train/images'),
        ann_file='/kaggle/working/data/train/_annotations.coco.json'))
        
val_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='val/images'),
        ann_file='/kaggle/working/data/val/_annotations.coco.json'))
        
test_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='val/images'),
        ann_file='/kaggle/working/data/val/_annotations.coco.json'))

val_evaluator = dict(ann_file="/kaggle/working/data/val/_annotations.coco.json")

test_evaluator = dict(ann_file="/kaggle/working/data/val/_annotations.coco.json")

model = dict(backbone=dict(frozen_stages=2), bbox_head=dict(num_classes=2))

optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=dict(
        type='AdamW',
        lr=0.0003/16,
        weight_decay=0.05),
    clip_grad=dict(max_norm=0.1/16, norm_type=2),
    paramwise_cfg=dict(custom_keys={'backbone': dict(lr_mult=0.1/16)})
)

default_hooks = dict(
    checkpoint=dict(
        interval=1,
        max_keep_ckpts=2,
        save_best='auto' , 
    ),
    logger=dict(type='LoggerHook', interval=2000))

load_from = './checkpoints/ddq_detr_swinl_30e.pth'

train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=max_epochs, val_interval=2)
randomness = dict(seed=2025, deterministic=False, diff_rank_seed=False)
"""

with open('./configs/ddq/ddq-detr-4scale_swinl_1xb1-15e_sky.py', 'w') as f:
    f.write(config_car)

# %%
# !python tools/train.py configs/ddq/ddq-detr-4scale_swinl_1xb1-15e_sky.py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 02/16 18:20:04 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 2025
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu116
#     OpenCV: 4.8.1
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2025
#     deterministic: False
#     diff_rank_seed: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/16 18:20:06 - mmengine - INFO - Config:
# dataset_type = 'CocoDataset'
# data_root = '/kaggle/working/data/'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(
#         type='ColorJitter',
#         brightness=0.2,
#         contrast=0.2,
#         saturation=0.2,
#         hue=0.1),
#     dict(type='CLAHE', clip_limit=2.0, tile_grid_size=(8, 8)),
#     dict(type='GaussianBlur', sigma_range=(0.1, 2.0)),
#     dict(
#         type='RandomAffine',
#         scaling=(0.9, 1.1),
#         translation=(0.1, 0.1),
#         rotate=(-20, 20)),
#     dict(
#         type='RandomBrightnessContrast',
#         brightness_limit=0.3,
#         contrast_limit=0.3,
#         prob=0.3),
#     dict(type='Sharpen', alpha=(0.1, 0.3), lightness=(0.75, 1.5)),
#     dict(
#         type='RandomChoice',
#         transforms=[[{
#             'type': 'RandomChoiceResize',
#             'scales': [(1280, 1280)],
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomChoiceResize',
#                         'scales': [(1280, 4200)],
#                         'keep_ratio': True
#                     }, {
#                         'type': 'RandomCrop',
#                         'crop_type': 'absolute_range',
#                         'crop_size': (384, 640),
#                         'allow_negative_crop': True
#                     }, {
#                         'type': 'RandomChoiceResize',
#                         'scales': [(1280, 1280)],
#                         'keep_ratio': True
#                     }]]),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1280, 1280), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/train/_annotations.coco.json',
#         data_prefix=dict(img='train/images'),
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='RandomChoice',
#                 transforms=[[{
#                     'type':
#                     'RandomChoiceResize',
#                     'scales': [(480, 1333), (512, 1333), (544, 1333),
#                                (576, 1333), (608, 1333), (640, 1333),
#                                (672, 1333), (704, 1333), (736, 1333),
#                                (768, 1333), (800, 1333)],
#                     'keep_ratio':
#                     True
#                 }],
#                             [{
#                                 'type': 'RandomChoiceResize',
#                                 'scales': [(400, 4200), (500, 4200),
#                                            (600, 4200)],
#                                 'keep_ratio': True
#                             }, {
#                                 'type': 'RandomCrop',
#                                 'crop_type': 'absolute_range',
#                                 'crop_size': (384, 600),
#                                 'allow_negative_crop': True
#                             }, {
#                                 'type':
#                                 'RandomChoiceResize',
#                                 'scales':
#                                 [(480, 1333), (512, 1333), (544, 1333),
#                                  (576, 1333), (608, 1333), (640, 1333),
#                                  (672, 1333), (704, 1333), (736, 1333),
#                                  (768, 1333), (800, 1333)],
#                                 'keep_ratio':
#                                 True
#                             }]]),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/val/_annotations.coco.json',
#         data_prefix=dict(img='val/images'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/val/_annotations.coco.json',
#         data_prefix=dict(img='val/images'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='/kaggle/working/data/val/_annotations.coco.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None)
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='/kaggle/working/data/val/_annotations.coco.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=2000),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=1, max_keep_ckpts=2, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = './checkpoints/ddq_detr_swinl_30e.pth'
# resume = False
# pretrained = 'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth'
# model = dict(
#     type='DDQDETR',
#     num_queries=900,
#     dense_topk_ratio=1.5,
#     with_box_refine=True,
#     as_two_stage=True,
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=1),
#     backbone=dict(
#         type='SwinTransformer',
#         pretrain_img_size=384,
#         embed_dims=192,
#         depths=[2, 2, 18, 2],
#         num_heads=[6, 12, 24, 48],
#         window_size=12,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.2,
#         patch_norm=True,
#         out_indices=(1, 2, 3),
#         with_cp=False,
#         convert_weights=True,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth'
#         ),
#         frozen_stages=2),
#     neck=dict(
#         type='ChannelMapper',
#         in_channels=[384, 768, 1536],
#         kernel_size=1,
#         out_channels=256,
#         act_cfg=None,
#         norm_cfg=dict(type='GN', num_groups=32),
#         num_outs=4),
#     encoder=dict(
#         num_layers=6,
#         layer_cfg=dict(
#             self_attn_cfg=dict(embed_dims=256, num_levels=4, dropout=0.0),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0))),
#     decoder=dict(
#         num_layers=6,
#         return_intermediate=True,
#         layer_cfg=dict(
#             self_attn_cfg=dict(embed_dims=256, num_heads=8, dropout=0.0),
#             cross_attn_cfg=dict(embed_dims=256, num_levels=4, dropout=0.0),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0)),
#         post_norm_cfg=None),
#     positional_encoding=dict(
#         num_feats=128, normalize=True, offset=0.0, temperature=20),
#     bbox_head=dict(
#         type='DDQDETRHead',
#         num_classes=2,
#         sync_cls_avg_factor=True,
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=5.0),
#         loss_iou=dict(type='GIoULoss', loss_weight=2.0)),
#     dn_cfg=dict(
#         label_noise_scale=0.5,
#         box_noise_scale=1.0,
#         group_cfg=dict(dynamic=True, num_groups=None, num_dn_queries=100)),
#     dqs_cfg=dict(type='nms', iou_threshold=0.8),
#     train_cfg=dict(
#         assigner=dict(
#             type='HungarianAssigner',
#             match_costs=[
#                 dict(type='FocalLossCost', weight=2.0),
#                 dict(type='BBoxL1Cost', weight=5.0, box_format='xywh'),
#                 dict(type='IoUCost', iou_mode='giou', weight=2.0)
#             ])),
#     test_cfg=dict(max_per_img=300))
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=1.875e-05, weight_decay=0.05),
#     clip_grad=dict(max_norm=0.00625, norm_type=2),
#     paramwise_cfg=dict(custom_keys=dict(backbone=dict(lr_mult=0.00625))))
# max_epochs = 50
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=50, val_interval=2)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.0001,
#         by_epoch=False,
#         begin=0,
#         end=2000),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=30,
#         by_epoch=True,
#         milestones=[20, 26],
#         gamma=0.1)
# ]
# auto_scale_lr = dict(base_batch_size=16)
# train_batch_size_per_gpu = 1
# train_num_workers = 2
# metainfo = dict(
#     classes=('head', 'shemagh'), palette=[(127, 201, 127), (190, 174, 212)])
# randomness = dict(seed=2025, deterministic=False, diff_rank_seed=False)
# launcher = 'none'
# work_dir = './work_dirs/ddq-detr-4scale_swinl_1xb1-15e_sky'
#
# 02/16 18:20:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/16 18:20:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 18:20:15 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.05
# ...
# 02/17 00:30:25 - mmengine - INFO - Saving checkpoint at 47 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 00:37:53 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_181959
# 02/17 00:37:53 - mmengine - INFO - Epoch(train) [48][516/516]  lr: 1.8750e-07  eta: 0:14:36  time: 0.8705  data_time: 0.0063  memory: 11991  grad_norm: 79.7324  loss: 1.3132  loss_cls: 0.0022  loss_bbox: 0.0308  loss_iou: 0.0307  d0.loss_cls: 0.0089  d0.loss_bbox: 0.0332  d0.loss_iou: 0.0321  d1.loss_cls: 0.0069  d1.loss_bbox: 0.0294  d1.loss_iou: 0.0303  d2.loss_cls: 0.0057  d2.loss_bbox: 0.0307  d2.loss_iou: 0.0306  d3.loss_cls: 0.0072  d3.loss_bbox: 0.0305  d3.loss_iou: 0.0308  d4.loss_cls: 0.0055  d4.loss_bbox: 0.0309  d4.loss_iou: 0.0307  enc_loss_cls: 0.0129  enc_loss_bbox: 0.0514  enc_loss_iou: 0.0481  dn_loss_cls: 0.0005  dn_loss_bbox: 0.0309  dn_loss_iou: 0.0305  d0.dn_loss_cls: 0.0082  d0.dn_loss_bbox: 0.0696  d0.dn_loss_iou: 0.0671  d1.dn_loss_cls: 0.0018  d1.dn_loss_bbox: 0.0342  d1.dn_loss_iou: 0.0343  d2.dn_loss_cls: 0.0009  d2.dn_loss_bbox: 0.0314  d2.dn_loss_iou: 0.0313  d3.dn_loss_cls: 0.0006  d3.dn_loss_bbox: 0.0306  d3.dn_loss_iou: 0.0306  d4.dn_loss_cls: 0.0006  d4.dn_loss_bbox: 0.0310  d4.dn_loss_iou: 0.0305  0_aux_aux_loss_cls: 0.0203  0_aux_aux_loss_bbox: 0.0311  1_aux_aux_loss_cls: 0.0133  1_aux_aux_loss_bbox: 0.0299  2_aux_aux_loss_cls: 0.0102  2_aux_aux_loss_bbox: 0.0306  3_aux_aux_loss_cls: 0.0068  3_aux_aux_loss_bbox: 0.0300  4_aux_aux_loss_cls: 0.0060  4_aux_aux_loss_bbox: 0.0301  5_aux_aux_loss_cls: 0.0044  5_aux_aux_loss_bbox: 0.0301  aux_enc_aux_loss_cls: 0.0367  aux_enc_aux_loss_bbox: 0.0497
# 02/17 00:37:53 - mmengine - INFO - Saving checkpoint at 48 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/dense_heads/detr_head.py:612: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   bbox_index = indexes // self.num_classes
# 02/17 00:38:47 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.80s).
# Accumulating evaluation results...
# DONE (t=0.59s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.816
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.882
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.861
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.923
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.923
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.948
# 02/17 00:38:48 - mmengine - INFO - bbox_mAP_copypaste: 0.816 0.882 0.861 0.391 0.758 0.855
# 02/17 00:38:48 - mmengine - INFO - Epoch(val) [48][135/135]    coco/bbox_mAP: 0.8160  coco/bbox_mAP_50: 0.8820  coco/bbox_mAP_75: 0.8610  coco/bbox_mAP_s: 0.3910  coco/bbox_mAP_m: 0.7580  coco/bbox_mAP_l: 0.8550  data_time: 0.0026  time: 0.3229
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 00:42:04 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_181959
# 02/17 00:46:09 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_181959
# 02/17 00:46:09 - mmengine - INFO - Epoch(train) [49][516/516]  lr: 1.8750e-07  eta: 0:07:18  time: 0.8527  data_time: 0.0065  memory: 11670  grad_norm: 87.7250  loss: 1.8912  loss_cls: 0.0005  loss_bbox: 0.0444  loss_iou: 0.0514  d0.loss_cls: 0.0036  d0.loss_bbox: 0.0446  d0.loss_iou: 0.0522  d1.loss_cls: 0.0028  d1.loss_bbox: 0.0445  d1.loss_iou: 0.0516  d2.loss_cls: 0.0019  d2.loss_bbox: 0.0447  d2.loss_iou: 0.0514  d3.loss_cls: 0.0007  d3.loss_bbox: 0.0451  d3.loss_iou: 0.0519  d4.loss_cls: 0.0006  d4.loss_bbox: 0.0445  d4.loss_iou: 0.0515  enc_loss_cls: 0.0107  enc_loss_bbox: 0.0561  enc_loss_iou: 0.0684  dn_loss_cls: 0.0008  dn_loss_bbox: 0.0388  dn_loss_iou: 0.0463  d0.dn_loss_cls: 0.0083  d0.dn_loss_bbox: 0.0702  d0.dn_loss_iou: 0.0786  d1.dn_loss_cls: 0.0028  d1.dn_loss_bbox: 0.0421  d1.dn_loss_iou: 0.0498  d2.dn_loss_cls: 0.0015  d2.dn_loss_bbox: 0.0392  d2.dn_loss_iou: 0.0470  d3.dn_loss_cls: 0.0009  d3.dn_loss_bbox: 0.0393  d3.dn_loss_iou: 0.0469  d4.dn_loss_cls: 0.0008  d4.dn_loss_bbox: 0.0388  d4.dn_loss_iou: 0.0464  0_aux_aux_loss_cls: 0.0475  0_aux_aux_loss_bbox: 0.0376  1_aux_aux_loss_cls: 0.0393  1_aux_aux_loss_bbox: 0.0372  2_aux_aux_loss_cls: 0.0437  2_aux_aux_loss_bbox: 0.0372  3_aux_aux_loss_cls: 0.0272  3_aux_aux_loss_bbox: 0.0383  4_aux_aux_loss_cls: 0.0246  4_aux_aux_loss_bbox: 0.0384  5_aux_aux_loss_cls: 0.0242  5_aux_aux_loss_bbox: 0.0383  aux_enc_aux_loss_cls: 0.0758  aux_enc_aux_loss_bbox: 0.0601
# 02/17 00:46:09 - mmengine - INFO - Saving checkpoint at 49 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 00:53:30 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_181959
# 02/17 00:53:30 - mmengine - INFO - Epoch(train) [50][516/516]  lr: 1.8750e-07  eta: 0:00:00  time: 0.8300  data_time: 0.0063  memory: 11989  grad_norm: 77.7452  loss: 2.3897  loss_cls: 0.0175  loss_bbox: 0.0435  loss_iou: 0.0570  d0.loss_cls: 0.0366  d0.loss_bbox: 0.0370  d0.loss_iou: 0.0534  d1.loss_cls: 0.0227  d1.loss_bbox: 0.0431  d1.loss_iou: 0.0587  d2.loss_cls: 0.0194  d2.loss_bbox: 0.0427  d2.loss_iou: 0.0546  d3.loss_cls: 0.0176  d3.loss_bbox: 0.0439  d3.loss_iou: 0.0569  d4.loss_cls: 0.0171  d4.loss_bbox: 0.0435  d4.loss_iou: 0.0571  enc_loss_cls: 0.0327  enc_loss_bbox: 0.0576  enc_loss_iou: 0.0790  dn_loss_cls: 0.0005  dn_loss_bbox: 0.0435  dn_loss_iou: 0.0583  d0.dn_loss_cls: 0.0095  d0.dn_loss_bbox: 0.0758  d0.dn_loss_iou: 0.0976  d1.dn_loss_cls: 0.0026  d1.dn_loss_bbox: 0.0475  d1.dn_loss_iou: 0.0644  d2.dn_loss_cls: 0.0011  d2.dn_loss_bbox: 0.0445  d2.dn_loss_iou: 0.0586  d3.dn_loss_cls: 0.0007  d3.dn_loss_bbox: 0.0438  d3.dn_loss_iou: 0.0590  d4.dn_loss_cls: 0.0006  d4.dn_loss_bbox: 0.0434  d4.dn_loss_iou: 0.0584  0_aux_aux_loss_cls: 0.0669  0_aux_aux_loss_bbox: 0.0519  1_aux_aux_loss_cls: 0.0580  1_aux_aux_loss_bbox: 0.0493  2_aux_aux_loss_cls: 0.0615  2_aux_aux_loss_bbox: 0.0460  3_aux_aux_loss_cls: 0.0555  3_aux_aux_loss_bbox: 0.0481  4_aux_aux_loss_cls: 0.0530  4_aux_aux_loss_bbox: 0.0474  5_aux_aux_loss_cls: 0.0520  5_aux_aux_loss_bbox: 0.0479  aux_enc_aux_loss_cls: 0.0761  aux_enc_aux_loss_bbox: 0.0749
# 02/17 00:53:30 - mmengine - INFO - Saving checkpoint at 50 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/dense_heads/detr_head.py:612: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   bbox_index = indexes // self.num_classes
# 02/17 00:54:24 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.81s).
# Accumulating evaluation results...
# DONE (t=0.60s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.860
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.943
# 02/17 00:54:26 - mmengine - INFO - bbox_mAP_copypaste: 0.814 0.881 0.860 0.391 0.758 0.853
# 02/17 00:54:26 - mmengine - INFO - Epoch(val) [50][135/135]    coco/bbox_mAP: 0.8140  coco/bbox_mAP_50: 0.8810  coco/bbox_mAP_75: 0.8600  coco/bbox_mAP_s: 0.3910  coco/bbox_mAP_m: 0.7580  coco/bbox_mAP_l: 0.8530  data_time: 0.0027  time: 0.3229
