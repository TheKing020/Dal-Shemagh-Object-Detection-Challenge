# %%
import pandas as pd

# %%
train = pd.read_csv('/kaggle/input/datasets/kagglertw/dal-shemagh/dal-shemagh-detection-challenge/train_labels.csv')

# %%
train['right_place'].value_counts()
# Out:
# right_place
# False    646
# True       5
# Name: count, dtype: int64

# %%
# !ls /kaggle/input/notebooks/kagglertw/shemagh-simple-ddq-map-50-o-inference5
# Out:
# custom.css		    __notebook__.ipynb	__results__.html
# __huggingface_repos__.json  __output__.json	submission.csv
# mmdetection		    __results___files

# %%
ps = pd.read_csv('/kaggle/input/notebooks/kagglertw/shemagh-simple-ddq-map-50-o-inference5/submission.csv')

# %%
ps = ps[ps['right_place']==1]

# %%
ps =ps[["filename"	,"right_place"	]]

# %%
ps =pd.concat([train , ps] , axis = 0)

# %%
ps['right_place'].value_counts()
# Out:
# right_place
# 0    646
# 1    180
# Name: count, dtype: int64

# %%
ps.to_csv('train_df.csv',index= False)

# %%
# !mkdir /kaggle/working/images

# %%
# !cp /kaggle/input/datasets/kagglertw/dal-shemagh/dal-shemagh-detection-challenge/images/train/*.jpg /kaggle/working/images

# %%
# !cp /kaggle/input/datasets/kagglertw/dal-shemagh/dal-shemagh-detection-challenge/images/test/*.jpg /kaggle/working/images
