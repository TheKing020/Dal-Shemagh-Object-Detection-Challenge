# %%
import IPython.display as display
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/torch-1.12.1+cu116-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/torchvision-0.13.1+cu116-cp310-cp310-linux_x86_64.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/mmcv-2.0.1-cp310-cp310-manylinux1_x86_64.whl 
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/openmim-0.3.9-py2.py3-none-any.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/mmengine-0.7.4-py3-none-any.whl
# !pip install --no-index --no-deps /kaggle/input/mmdetectron-31-wheel/addict-2.4.0-py3-none-any.whl
# !pip install yapf==0.40.1
display.clear_output()

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection
# !pip install -v -e .

# !mkdir checkpoint
# !mkdir outputs
# !mkdir data
# !mkdir data/images
# !mkdir data/labels

display.clear_output()

# %%
import torch, torchvision,mmdet
print("torch=",torch.__version__,torch.cuda.is_available())
print("mmdet=",mmdet.__version__)
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# torch= 1.12.1+cu116 True
# mmdet= 3.3.0
# 11.6
# GCC 9.3

# %%
import os
import io
import shutil
from PIL import Image

# %%
# !ls /kaggle/input/notebooks/kagglertw/dal-shemagh-2-f2
# Out:
# __notebook__.ipynb  __results__.html   custom.css
# __output__.json     __results___files  shemagh

# %%
from pycocotools.coco import COCO


annotation_file = '/kaggle/input/notebooks/kagglertw/dal-shemagh-2-f2/shemagh/train_dataset.json'


coco = COCO(annotation_file)


categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}


for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Category ID: 0, Category Name: head
# Category ID: 1, Category Name: shemagh

# %%
# !wget https://download.openmmlab.com/mmdetection/v3.0/ddq/ddq_detr_swinl_30e.pth -P ./checkpoints
display.clear_output()

# %%
from mmengine import Config
cfg = Config.fromfile('configs/ddq/ddq-detr-4scale_swinl_8xb2-30e_coco.py')

# %%
# !mkdir -p /kaggle/working/data
# !cp -r /kaggle/input/notebooks/kagglertw/data-management-5f/data_5fold/fold_2/* /kaggle/working/data/

# %%
# !ls /kaggle/input/notebooks/kagglertw/dal-shemagh-2-f2/shemagh
# Out:
# train  train_dataset.json  val	val_dataset.json

# %%
# !mkdir /kaggle/working/data
# Out:
# mkdir: cannot create directory '/kaggle/working/data': File exists

# %%
# !ls /kaggle/input/notebooks/kagglertw/data-management-5f/data_5fold/fold_2/
# Out:
# train  val

# %%
def count_png_files(folder_path):
    count = 0
    for file in os.listdir(folder_path):
        if file.lower().endswith(".jpg"):
            count += 1
    return count

# %%
# !mkdir /kaggle/working/data/val/images
# !mkdir /kaggle/working/data/train/images

# %%
# !mv /kaggle/working/data/val/*.jpg /kaggle/working/data/val/images/
# !mv /kaggle/working/data/train/*.jpg /kaggle/working/data/train/images/

# %%
# !ls /kaggle/working/data/val/
# Out:
# _annotations.coco.json	images

# %%
# !ls /kaggle/working/data/train/
# Out:
# _annotations.coco.json	images

# %%
# !ls /kaggle/working/data
# Out:
# train  val

# %%
count_png_files("/kaggle/working/data/val/images")
# Out:
# 131

# %%
count_png_files("/kaggle/working/data/train/images")
# Out:
# 520

# %%
config_car = """
_base_ = './ddq-detr-4scale_swinl_8xb2-30e_coco.py'

data_root = '/kaggle/working/data/'

train_batch_size_per_gpu = 1
train_num_workers = 2

max_epochs = 50

metainfo = {
    'classes': ('head', 'shemagh'),
    'palette': [(127,201,127),(190,174,212)]
}


train_pipeline = [
    dict(type='LoadImageFromFile', backend_args=_base_.backend_args),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='RandomFlip', prob=0.5),
    dict(type='ColorJitter', brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    dict(type='CLAHE', clip_limit=2.0, tile_grid_size=(8, 8)),
    dict(type='GaussianBlur', sigma_range=(0.1, 2.0)),
    dict(type='RandomAffine', scaling=(0.9, 1.1), translation=(0.1, 0.1), rotate=(-20, 20)),
    dict(type='RandomBrightnessContrast', brightness_limit=0.3, contrast_limit=0.3, prob=0.3),
    dict(type='Sharpen', alpha=(0.1, 0.3), lightness=(0.75, 1.5)),
    
    dict(
        type='RandomChoice',
        transforms=[
            [
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 1280)],
                    keep_ratio=True)
            ],
            [
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 4200)],
                    keep_ratio=True),
                dict(
                    type='RandomCrop',
                    crop_type='absolute_range',
                    crop_size=(384, 640),
                    allow_negative_crop=True),
                dict(
                    type='RandomChoiceResize',
                    scales=[(1280, 1280)],
                    keep_ratio=True)
            ]
        ]),
    dict(type='PackDetInputs')
]

test_pipeline = [
    dict(type='LoadImageFromFile', backend_args=None),
    dict(type='Resize', scale=(1280, 1280), keep_ratio=True),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(
        type='PackDetInputs',
        meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
                   'scale_factor'))
]

train_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='train/images'),
        ann_file='/kaggle/working/data/train/_annotations.coco.json'))
        
val_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='val/images'),
        ann_file='/kaggle/working/data/val/_annotations.coco.json'))
        
test_dataloader = dict(
    batch_size=train_batch_size_per_gpu,
    num_workers=train_num_workers,
    dataset=dict(
        data_root=data_root,
        metainfo=metainfo,
        data_prefix=dict(img='val/images'),
        ann_file='/kaggle/working/data/val/_annotations.coco.json'))

val_evaluator = dict(ann_file="/kaggle/working/data/val/_annotations.coco.json")

test_evaluator = dict(ann_file="/kaggle/working/data/val/_annotations.coco.json")

model = dict(backbone=dict(frozen_stages=2), bbox_head=dict(num_classes=2))

optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=dict(
        type='AdamW',
        lr=0.0003/16,
        weight_decay=0.05),
    clip_grad=dict(max_norm=0.1/16, norm_type=2),
    paramwise_cfg=dict(custom_keys={'backbone': dict(lr_mult=0.1/16)})
)

default_hooks = dict(
    checkpoint=dict(
        interval=1,
        max_keep_ckpts=2,
        save_best='auto' , 
    ),
    logger=dict(type='LoggerHook', interval=2000))

load_from = './checkpoints/ddq_detr_swinl_30e.pth'

train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=max_epochs, val_interval=2)
randomness = dict(seed=2025, deterministic=False, diff_rank_seed=False)
"""

with open('./configs/ddq/ddq-detr-4scale_swinl_1xb1-15e_sky.py', 'w') as f:
    f.write(config_car)

# %%
# !python tools/train.py configs/ddq/ddq-detr-4scale_swinl_1xb1-15e_sky.py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 02/16 19:11:26 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 | packaged by conda-forge | (main, Jun 23 2023, 22:40:32) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 2025
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu116
#     OpenCV: 4.8.1
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2025
#     deterministic: False
#     diff_rank_seed: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/16 19:11:28 - mmengine - INFO - Config:
# dataset_type = 'CocoDataset'
# data_root = '/kaggle/working/data/'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(
#         type='ColorJitter',
#         brightness=0.2,
#         contrast=0.2,
#         saturation=0.2,
#         hue=0.1),
#     dict(type='CLAHE', clip_limit=2.0, tile_grid_size=(8, 8)),
#     dict(type='GaussianBlur', sigma_range=(0.1, 2.0)),
#     dict(
#         type='RandomAffine',
#         scaling=(0.9, 1.1),
#         translation=(0.1, 0.1),
#         rotate=(-20, 20)),
#     dict(
#         type='RandomBrightnessContrast',
#         brightness_limit=0.3,
#         contrast_limit=0.3,
#         prob=0.3),
#     dict(type='Sharpen', alpha=(0.1, 0.3), lightness=(0.75, 1.5)),
#     dict(
#         type='RandomChoice',
#         transforms=[[{
#             'type': 'RandomChoiceResize',
#             'scales': [(1280, 1280)],
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomChoiceResize',
#                         'scales': [(1280, 4200)],
#                         'keep_ratio': True
#                     }, {
#                         'type': 'RandomCrop',
#                         'crop_type': 'absolute_range',
#                         'crop_size': (384, 640),
#                         'allow_negative_crop': True
#                     }, {
#                         'type': 'RandomChoiceResize',
#                         'scales': [(1280, 1280)],
#                         'keep_ratio': True
#                     }]]),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1280, 1280), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/train/_annotations.coco.json',
#         data_prefix=dict(img='train/images'),
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='RandomChoice',
#                 transforms=[[{
#                     'type':
#                     'RandomChoiceResize',
#                     'scales': [(480, 1333), (512, 1333), (544, 1333),
#                                (576, 1333), (608, 1333), (640, 1333),
#                                (672, 1333), (704, 1333), (736, 1333),
#                                (768, 1333), (800, 1333)],
#                     'keep_ratio':
#                     True
#                 }],
#                             [{
#                                 'type': 'RandomChoiceResize',
#                                 'scales': [(400, 4200), (500, 4200),
#                                            (600, 4200)],
#                                 'keep_ratio': True
#                             }, {
#                                 'type': 'RandomCrop',
#                                 'crop_type': 'absolute_range',
#                                 'crop_size': (384, 600),
#                                 'allow_negative_crop': True
#                             }, {
#                                 'type':
#                                 'RandomChoiceResize',
#                                 'scales':
#                                 [(480, 1333), (512, 1333), (544, 1333),
#                                  (576, 1333), (608, 1333), (640, 1333),
#                                  (672, 1333), (704, 1333), (736, 1333),
#                                  (768, 1333), (800, 1333)],
#                                 'keep_ratio':
#                                 True
#                             }]]),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/val/_annotations.coco.json',
#         data_prefix=dict(img='val/images'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/kaggle/working/data/',
#         ann_file='/kaggle/working/data/val/_annotations.coco.json',
#         data_prefix=dict(img='val/images'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('head', 'shemagh'),
#             palette=[(127, 201, 127), (190, 174, 212)])))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='/kaggle/working/data/val/_annotations.coco.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None)
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='/kaggle/working/data/val/_annotations.coco.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=2000),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', interval=1, max_keep_ckpts=2, save_best='auto'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = './checkpoints/ddq_detr_swinl_30e.pth'
# resume = False
# pretrained = 'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth'
# model = dict(
#     type='DDQDETR',
#     num_queries=900,
#     dense_topk_ratio=1.5,
#     with_box_refine=True,
#     as_two_stage=True,
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=1),
#     backbone=dict(
#         type='SwinTransformer',
#         pretrain_img_size=384,
#         embed_dims=192,
#         depths=[2, 2, 18, 2],
#         num_heads=[6, 12, 24, 48],
#         window_size=12,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.2,
#         patch_norm=True,
#         out_indices=(1, 2, 3),
#         with_cp=False,
#         convert_weights=True,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth'
#         ),
#         frozen_stages=2),
#     neck=dict(
#         type='ChannelMapper',
#         in_channels=[384, 768, 1536],
#         kernel_size=1,
#         out_channels=256,
#         act_cfg=None,
#         norm_cfg=dict(type='GN', num_groups=32),
#         num_outs=4),
#     encoder=dict(
#         num_layers=6,
#         layer_cfg=dict(
#             self_attn_cfg=dict(embed_dims=256, num_levels=4, dropout=0.0),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0))),
#     decoder=dict(
#         num_layers=6,
#         return_intermediate=True,
#         layer_cfg=dict(
#             self_attn_cfg=dict(embed_dims=256, num_heads=8, dropout=0.0),
#             cross_attn_cfg=dict(embed_dims=256, num_levels=4, dropout=0.0),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0)),
#         post_norm_cfg=None),
#     positional_encoding=dict(
#         num_feats=128, normalize=True, offset=0.0, temperature=20),
#     bbox_head=dict(
#         type='DDQDETRHead',
#         num_classes=2,
#         sync_cls_avg_factor=True,
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=5.0),
#         loss_iou=dict(type='GIoULoss', loss_weight=2.0)),
#     dn_cfg=dict(
#         label_noise_scale=0.5,
#         box_noise_scale=1.0,
#         group_cfg=dict(dynamic=True, num_groups=None, num_dn_queries=100)),
#     dqs_cfg=dict(type='nms', iou_threshold=0.8),
#     train_cfg=dict(
#         assigner=dict(
#             type='HungarianAssigner',
#             match_costs=[
#                 dict(type='FocalLossCost', weight=2.0),
#                 dict(type='BBoxL1Cost', weight=5.0, box_format='xywh'),
#                 dict(type='IoUCost', iou_mode='giou', weight=2.0)
#             ])),
#     test_cfg=dict(max_per_img=300))
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=1.875e-05, weight_decay=0.05),
#     clip_grad=dict(max_norm=0.00625, norm_type=2),
#     paramwise_cfg=dict(custom_keys=dict(backbone=dict(lr_mult=0.00625))))
# max_epochs = 50
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=50, val_interval=2)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.0001,
#         by_epoch=False,
#         begin=0,
#         end=2000),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=30,
#         by_epoch=True,
#         milestones=[20, 26],
#         gamma=0.1)
# ]
# auto_scale_lr = dict(base_batch_size=16)
# train_batch_size_per_gpu = 1
# train_num_workers = 2
# metainfo = dict(
#     classes=('head', 'shemagh'), palette=[(127, 201, 127), (190, 174, 212)])
# randomness = dict(seed=2025, deterministic=False, diff_rank_seed=False)
# launcher = 'none'
# work_dir = './work_dirs/ddq-detr-4scale_swinl_1xb1-15e_sky'
#
# 02/16 19:11:35 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/16 19:11:35 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr_mult=0.00625
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=1.1718749999999999e-07
# 02/16 19:11:37 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.05
# ...
# 02/17 01:23:58 - mmengine - INFO - Saving checkpoint at 47 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 01:31:30 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_191121
# 02/17 01:31:30 - mmengine - INFO - Epoch(train) [48][520/520]  lr: 1.8750e-07  eta: 0:14:42  time: 0.8562  data_time: 0.0060  memory: 11673  grad_norm: 59.8675  loss: 1.1502  loss_cls: 0.0024  loss_bbox: 0.0257  loss_iou: 0.0285  d0.loss_cls: 0.0030  d0.loss_bbox: 0.0265  d0.loss_iou: 0.0297  d1.loss_cls: 0.0021  d1.loss_bbox: 0.0261  d1.loss_iou: 0.0297  d2.loss_cls: 0.0028  d2.loss_bbox: 0.0266  d2.loss_iou: 0.0298  d3.loss_cls: 0.0024  d3.loss_bbox: 0.0258  d3.loss_iou: 0.0292  d4.loss_cls: 0.0026  d4.loss_bbox: 0.0257  d4.loss_iou: 0.0286  enc_loss_cls: 0.0101  enc_loss_bbox: 0.0373  enc_loss_iou: 0.0426  dn_loss_cls: 0.0003  dn_loss_bbox: 0.0261  dn_loss_iou: 0.0291  d0.dn_loss_cls: 0.0061  d0.dn_loss_bbox: 0.0573  d0.dn_loss_iou: 0.0607  d1.dn_loss_cls: 0.0012  d1.dn_loss_bbox: 0.0284  d1.dn_loss_iou: 0.0328  d2.dn_loss_cls: 0.0005  d2.dn_loss_bbox: 0.0273  d2.dn_loss_iou: 0.0305  d3.dn_loss_cls: 0.0003  d3.dn_loss_bbox: 0.0267  d3.dn_loss_iou: 0.0299  d4.dn_loss_cls: 0.0003  d4.dn_loss_bbox: 0.0262  d4.dn_loss_iou: 0.0291  0_aux_aux_loss_cls: 0.0150  0_aux_aux_loss_bbox: 0.0285  1_aux_aux_loss_cls: 0.0073  1_aux_aux_loss_bbox: 0.0282  2_aux_aux_loss_cls: 0.0086  2_aux_aux_loss_bbox: 0.0284  3_aux_aux_loss_cls: 0.0066  3_aux_aux_loss_bbox: 0.0282  4_aux_aux_loss_cls: 0.0073  4_aux_aux_loss_bbox: 0.0276  5_aux_aux_loss_cls: 0.0068  5_aux_aux_loss_bbox: 0.0277  aux_enc_aux_loss_cls: 0.0356  aux_enc_aux_loss_bbox: 0.0444
# 02/17 01:31:30 - mmengine - INFO - Saving checkpoint at 48 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/dense_heads/detr_head.py:612: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   bbox_index = indexes // self.num_classes
# 02/17 01:32:22 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.73s).
# Accumulating evaluation results...
# DONE (t=0.62s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.901
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.697
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.902
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.942
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.944
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.944
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.889
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.960
# 02/17 01:32:24 - mmengine - INFO - bbox_mAP_copypaste: 0.878 0.950 0.901 0.697 0.843 0.902
# 02/17 01:32:24 - mmengine - INFO - Epoch(val) [48][131/131]    coco/bbox_mAP: 0.8780  coco/bbox_mAP_50: 0.9500  coco/bbox_mAP_75: 0.9010  coco/bbox_mAP_s: 0.6970  coco/bbox_mAP_m: 0.8430  coco/bbox_mAP_l: 0.9020  data_time: 0.0025  time: 0.3224
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 01:32:58 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_191121
# 02/17 01:39:46 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_191121
# 02/17 01:39:46 - mmengine - INFO - Epoch(train) [49][520/520]  lr: 1.8750e-07  eta: 0:07:21  time: 0.8484  data_time: 0.0064  memory: 11990  grad_norm: 71.9590  loss: 1.7414  loss_cls: 0.0010  loss_bbox: 0.0519  loss_iou: 0.0390  d0.loss_cls: 0.0027  d0.loss_bbox: 0.0499  d0.loss_iou: 0.0394  d1.loss_cls: 0.0015  d1.loss_bbox: 0.0498  d1.loss_iou: 0.0380  d2.loss_cls: 0.0016  d2.loss_bbox: 0.0517  d2.loss_iou: 0.0390  d3.loss_cls: 0.0011  d3.loss_bbox: 0.0514  d3.loss_iou: 0.0391  d4.loss_cls: 0.0011  d4.loss_bbox: 0.0519  d4.loss_iou: 0.0392  enc_loss_cls: 0.0100  enc_loss_bbox: 0.0594  enc_loss_iou: 0.0542  dn_loss_cls: 0.0012  dn_loss_bbox: 0.0610  dn_loss_iou: 0.0435  d0.dn_loss_cls: 0.0086  d0.dn_loss_bbox: 0.0965  d0.dn_loss_iou: 0.0780  d1.dn_loss_cls: 0.0022  d1.dn_loss_bbox: 0.0624  d1.dn_loss_iou: 0.0469  d2.dn_loss_cls: 0.0014  d2.dn_loss_bbox: 0.0614  d2.dn_loss_iou: 0.0445  d3.dn_loss_cls: 0.0011  d3.dn_loss_bbox: 0.0602  d3.dn_loss_iou: 0.0438  d4.dn_loss_cls: 0.0011  d4.dn_loss_bbox: 0.0610  d4.dn_loss_iou: 0.0435  0_aux_aux_loss_cls: 0.0078  0_aux_aux_loss_bbox: 0.0404  1_aux_aux_loss_cls: 0.0050  1_aux_aux_loss_bbox: 0.0392  2_aux_aux_loss_cls: 0.0055  2_aux_aux_loss_bbox: 0.0393  3_aux_aux_loss_cls: 0.0043  3_aux_aux_loss_bbox: 0.0399  4_aux_aux_loss_cls: 0.0034  4_aux_aux_loss_bbox: 0.0396  5_aux_aux_loss_cls: 0.0027  5_aux_aux_loss_bbox: 0.0395  aux_enc_aux_loss_cls: 0.0292  aux_enc_aux_loss_bbox: 0.0545
# 02/17 01:39:46 - mmengine - INFO - Saving checkpoint at 49 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/task_modules/assigners/topk_hungarian_assigner.py:144: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   match_gt_ids = matched_col_inds // topk
# 02/17 01:47:16 - mmengine - INFO - Exp name: ddq-detr-4scale_swinl_1xb1-15e_sky_20260216_191121
# 02/17 01:47:16 - mmengine - INFO - Epoch(train) [50][520/520]  lr: 1.8750e-07  eta: 0:00:00  time: 0.8676  data_time: 0.0061  memory: 11623  grad_norm: 71.9680  loss: 0.9041  loss_cls: 0.0032  loss_bbox: 0.0197  loss_iou: 0.0189  d0.loss_cls: 0.0030  d0.loss_bbox: 0.0225  d0.loss_iou: 0.0221  d1.loss_cls: 0.0026  d1.loss_bbox: 0.0189  d1.loss_iou: 0.0191  d2.loss_cls: 0.0026  d2.loss_bbox: 0.0191  d2.loss_iou: 0.0189  d3.loss_cls: 0.0026  d3.loss_bbox: 0.0195  d3.loss_iou: 0.0192  d4.loss_cls: 0.0028  d4.loss_bbox: 0.0197  d4.loss_iou: 0.0189  enc_loss_cls: 0.0058  enc_loss_bbox: 0.0407  enc_loss_iou: 0.0387  dn_loss_cls: 0.0002  dn_loss_bbox: 0.0205  dn_loss_iou: 0.0199  d0.dn_loss_cls: 0.0069  d0.dn_loss_bbox: 0.0629  d0.dn_loss_iou: 0.0568  d1.dn_loss_cls: 0.0014  d1.dn_loss_bbox: 0.0253  d1.dn_loss_iou: 0.0246  d2.dn_loss_cls: 0.0006  d2.dn_loss_bbox: 0.0213  d2.dn_loss_iou: 0.0211  d3.dn_loss_cls: 0.0003  d3.dn_loss_bbox: 0.0209  d3.dn_loss_iou: 0.0205  d4.dn_loss_cls: 0.0002  d4.dn_loss_bbox: 0.0205  d4.dn_loss_iou: 0.0199  0_aux_aux_loss_cls: 0.0090  0_aux_aux_loss_bbox: 0.0225  1_aux_aux_loss_cls: 0.0069  1_aux_aux_loss_bbox: 0.0196  2_aux_aux_loss_cls: 0.0069  2_aux_aux_loss_bbox: 0.0193  3_aux_aux_loss_cls: 0.0062  3_aux_aux_loss_bbox: 0.0192  4_aux_aux_loss_cls: 0.0063  4_aux_aux_loss_bbox: 0.0189  5_aux_aux_loss_cls: 0.0067  5_aux_aux_loss_bbox: 0.0188  aux_enc_aux_loss_cls: 0.0194  aux_enc_aux_loss_bbox: 0.0422
# 02/17 01:47:16 - mmengine - INFO - Saving checkpoint at 50 epochs
# /kaggle/working/mmdetection/mmdet/models/layers/positional_encoding.py:103: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature**(2 * (dim_t // 2) / self.num_feats)
# /kaggle/working/mmdetection/mmdet/models/layers/transformer/utils.py:71: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = temperature**(2 * (dim_t // 2) / num_feats)
# /kaggle/working/mmdetection/mmdet/models/dense_heads/detr_head.py:612: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   bbox_index = indexes // self.num_classes
# 02/17 01:48:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.76s).
# Accumulating evaluation results...
# DONE (t=0.64s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.902
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.942
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.943
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.943
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.886
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.960
# 02/17 01:48:10 - mmengine - INFO - bbox_mAP_copypaste: 0.878 0.950 0.900 0.714 0.843 0.902
# 02/17 01:48:10 - mmengine - INFO - Epoch(val) [50][131/131]    coco/bbox_mAP: 0.8780  coco/bbox_mAP_50: 0.9500  coco/bbox_mAP_75: 0.9000  coco/bbox_mAP_s: 0.7140  coco/bbox_mAP_m: 0.8430  coco/bbox_mAP_l: 0.9020  data_time: 0.0024  time: 0.3224
